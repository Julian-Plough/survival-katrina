# %%
import pandas as pd
import pyreadstat

# %%
infl, meta = pyreadstat.read_dta("D:/Dissertation(!)/Paper 3/inflation_6_21.dta")
print(infl.shape)
infl.head()
# Out:
# (353, 3)
#    l_year  l_month  inflation_6_21
# 0    1992        1            1.97
# 1    1992        2            1.96
# 2    1992        3            1.95
# 3    1992        4            1.95
# 4    1992        5            1.94

# %%
df = pd.read_parquet("../data/processed/assembled.parquet")
print(df.shape)
df.head()
# Out:
# (327747, 58)
#      geopin  move_in  move_out  purchase_price  sale_price    name    type  \
# 0  41049784     9009    9065.0             NaN         NaN  Joseph  Street
# 1  41049784     9065   11893.0             NaN         NaN  Joseph  Street
# 2  41049784    11893   15931.0             NaN         0.0  Joseph  Street
# 3  41049784    15931   15964.0             0.0         0.0  Joseph  Street
# 4  41049784    15964   19184.0             0.0    495957.0  Joseph  Street
#
#   zoningclassification                               zoningdescription  \
# 0               HU-RD2  Historic Urban Two-Family Residential District
# 1               HU-RD2  Historic Urban Two-Family Residential District
# 2               HU-RD2  Historic Urban Two-Family Residential District
# 3               HU-RD2  Historic Urban Two-Family Residential District
# 4               HU-RD2  Historic Urban Two-Family Residential District
#
# ...

# %%
print(df['l_date'].dtype)
print(df['l_date'].dropna().head(10))
# Out:
# float64
# 6     15281.0
# 10    14221.0
# 11    15705.0
# 14    18221.0
# 15    18962.0
# 20    12689.0
# 21    15643.0
# 26    15932.0
# 27    15932.0
# 29    19697.0
# Name: l_date, dtype: float64
